# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("cereal.xlsx", sheet_name='Modified_Cereal', index_col=0)
data.head(5)
# Out:
#                            calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran                        70        4    1     130   10.0    5.0
# 100% Natural Bran               120        3    5      15    2.0    8.0
# All-Bran                         70        4    1     260    9.0    7.0
# All-Bran with Extra Fiber        50        4    0     140   14.0    8.0
# Almond Delight                  110        2    2     200    1.0   14.0
#
#                            sugars  potass  vitamins  weight  cups     rating
# name
# 100% Bran                       6     280        25     1.0  0.33  68.402973
# 100% Natural Bran               8     135         0     1.0  1.00  33.983679
# All-Bran                        5     320        25     1.0  0.33  59.425505
# All-Bran with Extra Fiber       0     330        25     1.0  0.50  93.704912
# Almond Delight                  8       0        25     1.0  0.75  34.384843

# %%
calories = data['calories']

# %%
protein = data['protein']

# %%
bar = data.loc[:, ['calories', 'protein', 'fat']].plot(kind='barh', stacked=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-004135d07e1c> in <module>
# ----> 1 bar.index()
#
# AttributeError: 'AxesSubplot' object has no attribute 'index'

# %%
calories.plot(kind='barh', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-63362c0b1db1> in <module>
# ----> 1 (calories,protein).plot(kind='barh', stacked=True)
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
#data['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins'].plot(kind='barh', stacked=True)
