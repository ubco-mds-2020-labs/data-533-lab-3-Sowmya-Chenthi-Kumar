# %%
import unittest
from Find_Module1 import TestRecommend
from Find_Module2 import TestDeficiency
def my_suite():
    suite=unittest.TestSuite()
    result=unittest.TestResult()
    suite.addTest(unittest.makeSuite(TestRecommend))
    suite.addTest(unittest.makeSuite(TestDeficiency))
    runner=unittest.TextTestRunner()
    print(runner.run(suite))
my_suite()
# Out:
# ..
# Setup class method
# Printing the setup statement
# Done testing the my_cereal method
# Printing Teardown statement
# Printing the setup statement
# Done testing the recommend method
# Printing Teardown statement
# Teardown class method
# Hi! Sowmya OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hi Murali OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
# .
# Hey!!Ana You are having all the required nutrient contents! Way to go!
#
# Hi Dave OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hi! Sowmya OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hi Murali OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hey!!Ana You are having all the required nutrient contents! Way to go!
#
# Hi Dave OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
# .
# Hi! Sowmya OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hi Murali OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
#
# Hey!!Ana You are having all the required nutrient contents! Way to go!
#
# Hi Dave OOPS! Your nutrient levels are not up to the mark!
# You are deficient by:
# .
# ----------------------------------------------------------------------
# Ran 5 tests in 1.259s
#
# OK
# <unittest.runner.TextTestResult run=5 errors=0 failures=0>
