# %%
import pandas as pd
import matplotlib.pyplot as plt
class Cereals_nutrition1:
    def display_Cereals(self):
        data = pd.read_excel("cereal.xlsx", sheet_name='Modified_Cereal', index_col=0)
        bar = data.loc[:, ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']]
        fig = bar.plot(kind='barh', stacked=True, figsize=(12,12), title="Nutrient composition of cereals")
        fig.set_ylabel("Cereals")

        #for p in fig.patches:
            
        #fig.append(p.get_height())
            #print(p.get_width())
            
        return plt.gca()
    
            #print(p.get_xticklabels())
        #fig.annotate(str(round(p.get_height())), (p.get_x() * 1.005, p.get_height() * 1.005))
        
        #return x
        #bar.ylabel("Nutrient composition of cereals")

# %%
c1 = Cereals_nutrition1()
x= c1.display_Cereals()

# %%
nutrients= x.patches

calories = nutrients[:74]
protein = nutrients[74:2*74]
fat = nutrients[2*74:3*74]
sodium = nutrients[3*74:4*74]

print(calories[0].get_width())
print(protein[0].get_width())
print(fat[0].get_width())
print(sodium[0].get_width())


#for p in x.patches:
#for p in protein:
    #print(p.get_width())
# Out:
# 70.0
# 4.0
# 1.0
# 130.0

# %%
data = pd.read_excel("cereal.xlsx", sheet_name='Modified_Cereal', index_col=0)

# %%
bar = data.loc[:, ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']]
fig = bar.plot(kind='barh', stacked=True, figsize=(12,12), title="Nutrient composition of cereals")
        
fig.set_ylabel("Cereals")
# Out:
# Text(0, 0.5, 'Cereals')

# %%
fig.axes[0].yaxis.get_major_ticks()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-a52003672b65> in <module>
# ----> 1 fig.axes[0].yaxis.get_major_ticks()[0]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
plt.gca()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-633c5a9848a0> in <module>
# ----> 1 fig.gca()
#
# AttributeError: 'AxesSubplot' object has no attribute 'gca'

# %%
print (plt.gca().get_title())

# %%
data.iloc[0,0]
# Out:
# 70
